# %% [markdown]
# <a href="https://colab.research.google.com/github/hal-yu/datasci_1_loading/blob/main/HHA507W1_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Acquistion

# %% [markdown]
# 1. Find and download at least 2-3 different CSV datasets (less than 10MB each) that do not contain any PHI/PII.
# 2. Similarly, find and download 3 XLSX files and 3 JSON files with the same criteria.
# 3. Use pandas to load each of these datasets into separate data frames in your Colab notebook.
# 4. Display the first 10 rows of each dataset in separate code cells.

# %%
import pandas as pd
import seaborn as sns
import plotly as plt

# %% [markdown]
# ## *CSV Datasets*

# %%
# !pip freeze > packagestxt

# %% [markdown]
# ### Top Rated Movies

# %% [markdown]
# #### Brief Description of Columns
# *   'ID' is the ID number of the movie
# *   'Genre ID' is the ID number of the genre
# *   'Title' refers to the full title of the movie
# *   'Overview' is the brief description of each movie
# *   'Popularity' is the popularity rating of the movie
# *   'Release Date' is the release date of the movie
# *   'Vote_Average' is the avreage ratings out of 10
# *   'Vote_Count' is the total number of vote counts

# %%
df1 = pd.read_csv('CSV_Datasets/MoviesTopRated.csv')
df1.head(10)
# Out:
#    Unnamed: 0      id         genre_ids                        title  \
# 0           0     238          [18, 80]                The Godfather
# 1           1     278          [18, 80]     The Shawshank Redemption
# 2           2     240          [18, 80]        The Godfather Part II
# 3           3     424   [18, 36, 10752]             Schindler's List
# 4           4   19404   [35, 18, 10749]  Dilwale Dulhania Le Jayenge
# 5           5     389              [18]                 12 Angry Men
# 6           6     129   [16, 10751, 14]                Spirited Away
# 7           7  372058   [10749, 16, 18]                   Your Name.
# 8           8  496243      [35, 53, 18]                     Parasite
# 9           9     155  [18, 28, 80, 53]              The Dark Knight
#
#                                             overview  popularity release_date  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     119.438   1972-03-14
# ...

# %% [markdown]
# ### Crimes Data

# %% [markdown]
# #### Brief Description of Columns
# *   'Year' is the year of crime from 2000-2019
# *   'Population' is the number of people according to bureau of statistics
# *   'Violent Crimes' is the number of violent crimes
# *   'Violent Crime Rate' is the rate per 100000
# *   'Murder Nonnegligent Manslaughter' is the number of murder cases per year
# *   'Murder Nonngeligent Manslaughter Rate' is the rate of murder nonnegligent manslaughter
# *   'Rape' is the number of rape cases
# *   'Rape Rate' is the rate of the rape cases per 100000 persons
# *   'Robbery' is the number of robbery cases
# *   'Robbery rate' is the number of robbery cases per 100000 persons
# *   'Aggravate assault' is the number of aggravated assault cases
# *   'Aggravated assault rate' is the rate of aggravated assault per 100000 persons
# *   'Property crime' is the numbers of property stolen crimes reported per year.
# *   'Property crime rate is the rate of property theft per 100,000 persons
# *   'Burglary' is the number burglary recorded per year
# *   'Burglary rate' is the burglary rate per 100000 persons
# *   'Burglary rate' is the burglary rate per 100000 persons
# *   'Larceny-theft' is the numbers of larceny theft per year
# *   'Larceny-theft rate' is the larceny theft rate per 100000 people
# *   'Motor vehicle theft' is the numbers of motor stolen per year
# *   'Motor vehicle theft rate' is the motor vehicle theft rate per 100000 persons

# %%
df2 = pd.read_csv('CSV_Datasets/crimes.dataset.csv')
df2.head(10)
# Out:
#    Year   Population Violent Crimes  Violent crime rate  \
# 0  2000  281,421,906      1,425,486               506.5
# 1  2001  285,317,559      1,439,480               504.5
# 2  2002  287,973,924      1,423,677               494.4
# 3  2003  290,788,976      1,383,676               475.8
# 4  2004  293,656,842      1,360,088               463.2
# 5  2005  296,507,061      1,390,745               469.0
# 6  2006  299,398,484      1,435,123               479.3
# 7  2007  301,621,157      1,422,970               471.8
# 8  2008  304,059,724      1,394,461               458.6
# 9  2009  307,006,550      1,325,896               431.9
#
#   Murder nonnegligent manslaughter  Murder nonnegligent manslaughter rate  \
# 0                           15,586                                    5.5
# 1                           16,037                                    5.6
# 2                           16,229                                    5.6
# ...

# %% [markdown]
# ### Provisional Drug Overdose Death Counts

# %% [markdown]
# *   'Country' is the location being analyzed
# *   'Vaccinated' is the vaccinated population
# *   'FullyVaccinated' is the fully vaccinated population
# *   'AdditionalDosagePer100 People' is the additional doses for every 100 people
# *   'AdditionalDosageTotal' is the total amount of people that received additional dosages
# *   'DosesAdministeredPer100People' is the amount of people that receieved vaccinations per 100 people
# *   'DosesAdministeredTotal' is the total amount of people that received vaccination

# %%
df3 = pd.read_csv('CSV_Datasets/CovidVaccinations2023.csv')
df3.head(10)
# Out:
#     Country Vaccinated FullyVaccinated AdditionalDosesPer100people  \
# 0     World        72%             67%                          35
# 1     Macau       >99%            >99%                          76
# 2    Brunei       >99%            >99%                          78
# 3    U.A.E.       >99%            >99%                          53
# 4     Qatar       >99%            >99%                          67
# 5     Samoa     97.00%          90.00%                          42
# 6     Nepal        97%             85%                          32
# 7     Chile     95.00%          93.00%                         145
# 8     Malta        95%             94%                          92
# 9  Portugal     95.00%          87.00%                          69
#
#   AdditionalDosesTotal  DosesAdministeredPer100people  DosesAdministeredTotal
# 0           2716491503                          173.0             13270170332
# ...

# %% [markdown]
# ## *XLSX Files*

# %% [markdown]
# ### Healthcare Diabetes Dataset

# %% [markdown]
# #### Brief Description of Columns
#
# *   'ID' is the unique identifier
# *   'Pregnancies' is the number of pregnancies of the ID
# *   'Glucose' is the plasma glucose concentration from a 2-hour test
# *   'BloodPressure' is the diastolic bloodpressure (mmHg)
# *   'SkinThickness' is the triceps skinfold thickness(mm)
# *   'Insulin' is the 2-hour serum insulin (muU/ml)
# *   'BMI' is the body mass index (kg/m^2)
# *   'DiabetesPedigreeFunction' is the diabetes pedigree function, a genetic score of diabetes
# *   'Age' is the age in years
# *   'Outcome; is the binary classification indicating the presence (1) or absence (0) of diabetes

# %%
df4 = pd.read_excel('XLSX_Datasets/diabetes.xlsx')
df4.head(10)
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
# 5   6            5      116             74              0        0  25.6
# 6   7            3       78             50             32       88  31.0
# 7   8           10      115              0              0        0  35.3
# 8   9            2      197             70             45      543  30.5
# 9  10            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %% [markdown]
# ### Drug Dataset

# %% [markdown]
# #### Brief Description of Columns
# *   'Age' is the age of the patient
# *   'Sex' is thegender of the patient
# *   'BP' is the blood pressure levels
# *   'Cholesterol' is the cholesterol levels
# *   'Na_to_K' is the sodium to potassium ratio in blood
# *   'Drug' is the drug type

# %%
df5 = pd.read_excel('XLSX_Datasets/drug.xlsx')
df5.head(10)
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY
# 5   22   F  NORMAL        HIGH    8.607  drugX
# 6   49   F  NORMAL        HIGH   16.275  DrugY
# 7   41   M     LOW        HIGH   11.037  drugC
# 8   60   M  NORMAL        HIGH   15.171  DrugY
# 9   43   M     LOW      NORMAL   19.368  DrugY

# %% [markdown]
# ### Valorant Esports

# %% [markdown]
# #### Brief Description of Columns
#
#
# *   'Rank' is the place the teams rank by earnings
# *   'Team; is the name of the team
# *   'Gold' is the number of event where they ranked 1st
# *   'Silver' is the number of events where the team finished 2nd
# *   'Bronze' is the number of events where they finished 3rd
# *   'S Tier' is the number of events where the team finished in 1st at a major event
# *   'Earnings' is the total money won in valorant esports

# %%
df6 = pd.read_excel('XLSX_Datasets/val.xlsx')
df6.head(10)
# Out:
#    Rank             Team  Gold  Silver  Bronze  S Tier  Earnings
# 0     1        Sentinels    12       3       1       1    561500
# 1     2            Acend     5       1       1       1    498859
# 2     3   Gambit Esports     8       3       0       1    495638
# 3     4      Team Liquid     4       2       2       0    295374
# 4     5       G2 Esports     7       2       1       0    257925
# 5     6        Team Envy     2       2       2       0    251500
# 6     7      100 Thieves     2       3       2       0    225000
# 7     8  Vision Strikers    17       0       0       0    224149
# 8     9           Fnatic     1       2       2       0    210888
# 9    10      KRÜ Esports     7       3       1       0    191000

# %% [markdown]
# ## *JSON Files*

# %%
import json

# %% [markdown]
# ### Recipie Ingredients Dataset

# %% [markdown]
# #### Brief Description of Columns
# *   'ID' is the recipie ID
# *   'Cuisine' is the type of cuisine
# *   'Ingredients' are the list of ingredients used in the recipie

# %%
df7 = pd.read_json('JSON_Datasets/Recipie.json', lines=False)
df7.head(10)
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# 5   6602     jamaican  [plain flour, sugar, butter, eggs, fresh ginge...
# 6  42779      spanish  [olive oil, salt, medium shrimp, pepper, garli...
# 7   3735      italian  [sugar, pistachio nuts, white almond bark, flo...
# 8  16903      mexican  [olive oil, purple onion, fresh pineapple, por...
# 9  12734      italian  [chopped tomatoes, fresh basil, garlic, extra-...

# %% [markdown]
# ### Epidemic Question Answering Datasheets

# %% [markdown]
# #### Brief Description of Columns
# *   'question_id' is the ID of the question
# *   'question' is the question that was asked
# *   'query' is the general term the question falls under
# *   'background' is the reason for asking the question

# %%
df8 = pd.read_json('JSON_Datasets/consumer_questions_prelim.json')
df8.head(10)
# Out:
#   question_id                                           question  \
# 0       CQ001                     what is the origin of COVID-19
# 1       CQ002  how does the coronavirus respond to changes in...
# 2       CQ003   will SARS-CoV2 infected people develop immunity?
# 3       CQ004            how do people die from the coronavirus?
# 4       CQ005  are there any drugs that work for SARS-CoV or ...
# 5       CQ006  what types of rapid testing for COVID-19 have ...
# 6       CQ007  are there blood tests that detect antibodies t...
# 7       CQ008  has testing availability lead to underreportin...
# 8       CQ009                   how has COVID-19 affected Canada
# 9       CQ010  has social distancing had an impact on slowing...
#
#                                      query  \
# 0                       coronavirus origin
# 1  coronavirus response to weather changes
# 2                     coronavirus immunity
# 3   how do people die from the coronavirus
# ...

# %% [markdown]
# ### Tech Company Mission Statements and Values

# %% [markdown]
# *   'name' is the company name
# *   'socials' is the list of company social medias
# *   'about' is the formal introduction of the company
# *   'statement' is the mission and vision statement that the company has stated
# *   'values' are values that the company believes in
# *   'offer' is the list of perks and benefits known from the company

# %%
df9 = pd.read_json('JSON_Datasets/workattech-company-2022_12_21.json')
df9.head(10)
# Out:
#         name                                            socials founded  \
# 0       Acko  [[Website, https://acko.com/], [Twitter, https...    2016
# 1      Adobe  [[Website, https://adobe.com/], [Twitter, http...    1982
# 2     Airbnb  [[Website, https://airbnb.com/], [Twitter, htt...    2007
# 3     Amazon  [[Website, https://amazon.com/], [Twitter, htt...    1994
# 4     Amdocs  [[Website, https://amdocs.com/], [Twitter, htt...    1982
# 5  AngelList  [[Website, https://angellist.com/], [Twitter, ...    2010
# 6       Apna  [[Website, https://apna.co/], [Twitter, https:...    2019
# 7      Apple  [[Website, https://apple.com/], [Twitter, http...    1976
# 8   Arcesium  [[Website, https://arcesium.com/], [Twitter, h...    2015
# 9  Atlassian  [[Website, https://atlassian.com/], [Twitter, ...    2002
#
#    employees                                              about  \
# 0   501 - 1K  ACKO is India’s first and fastest-growing Insu...
# ...
